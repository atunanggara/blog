# %% [raw]
# ---
# aliases:
# - /2021/02/02/pylint_function
# date: '2021-02-02'
# description: Thoughts on using pylint for function
# categories:
# - python
# - pylint
# - reflection
# image: images/thumbnails/function_drawing.jpg
# toc: true
# draft: true
# output-file: 2021-02-02-pylint_function.html
# title: Functioning Code via Pylint
#
# ---

# %% [markdown]
# # Summary
#
# Thinking through the 15 local variables and 5 parameters restrictions from pylint.

# %% [markdown]
# # Introduction
#
# My inspiration to write again comes from reading through the [Google Slides from Vicki Boykis's Rstudio Global 2021 talk](https://docs.google.com/presentation/d/1RZqE43Y3fWEExGwL3jAZD7uQPDUnt53UZj0GgWo6RtQ/edit#slide=id.g6fe1a5a715_4_4744). Specifically, she wrote,
# >Often, in the process of writing something, you learn about it a bit more, as well.
#
# So, with that in mind, if I were to write for [my 6-months-ago me](https://www.fast.ai/2019/05/13/blogging-advice/), I want to let me know that it might be good to understand [`pylint`](https://www.pylint.org/) [R0913](https://vald-phoenix.github.io/pylint-errors/plerr/errors/design/R0913.html) (`too-many-arguments`) and [R0914](https://vald-phoenix.github.io/pylint-errors/plerr/errors/design/R0914) (`too-many-locals`) mean.
#
# To provide context, [`pylint`](https://pypi.org/project/pylint/) is "a Python static code analysis tool which looks for programming errors, helps enforcing a coding standard, sniffs for code smells and offers simple refactoring suggestions." It is a way for me as a Python coder to ensure that my code is of the highest quality.
